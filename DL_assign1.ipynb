# %% [markdown]
# # [Assignment 1 - Design Perceptron to Learn Logic Gates](https://www.enjoyalgorithms.com/blog/design-perceptron-to-learn-and-or-xor-gates)
#
# ---

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import tensorflow as tf
# Out:
# 2026-01-16 12:32:19.645752: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-01-16 12:32:19.789272: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-01-16 12:32:22.464795: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.

# %%
T = 1.0

# %% [markdown]
# ## Designing single-Layer perceptron from scratch
#
# ---

# %%
class Perceptron:
    def __init__(self, lr=0.1, n_iter=1000):
        self.lr = lr
        self.epochs = n_iter
        self.weights = None
        self.bias = None

    def
